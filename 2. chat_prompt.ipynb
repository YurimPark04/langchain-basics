# %%
# %pip install -q langchain-ollama
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_ollama import ChatOllama

llm = ChatOllama(model="deepseek-r1:1.5b")  
llm.invoke("What is the capital of France?") # 프롬프트 : LLM호출
# Out:
# AIMessage(content="The capital of France is Paris. It is a significant city in the country, located in the south, and serves as the capital of the Seine region. Although the question focused on the capital of France, it's important to note that Paris remains the official capital, with the first letter capitalized. The political structure of France as a republic means the government is composed of the President, Prime Minister, and Prime Minister of the Government. The capital's status as Paris is consistent, even though it is often referred to as the capital of a specific region.", additional_kwargs={}, response_metadata={'model': 'deepseek-r1:1.5b', 'created_at': '2026-03-12T16:53:31.0934325Z', 'done': True, 'done_reason': 'stop', 'total_duration': 30441981300, 'load_duration': 304157000, 'prompt_eval_count': 10, 'prompt_eval_duration': 39613200, 'eval_count': 820, 'eval_duration': 29638023100, 'logprobs': None, 'model_name': 'deepseek-r1:1.5b', 'model_provider': 'ollama'}, id='lc_run--019ce2f7-4068-7893-98ca-289965c71685-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 10, 'output_tokens': 820, 'total_tokens': 830})

# %%
# ValueError: Invalid input type <class 'int'>. Must be a PromptValue, str, or list of BaseMessages.
# -> invoke 할때 나름의 입력형식이 정해져 있다.

# %%
# PromptValue -> PRomptTemplate을 활용하면 만들 수 있다

# %%
from langchain_core.prompts import PromptTemplate

prompt_template = PromptTemplate(
    template = "What is the capital of {country}?",  # {country} : placeholder -> 대입을 해줘야 한다. HOW?
    input_variables=["country"],
)

## LLM에 invoke 한 것처럼, 프롬프트도 invoke를 해줘야 한다 
prompt = prompt_template.invoke({"country":"France"})  # prompt 가 promptValue가 됨
print(prompt)  # output : text='What is the capital of France?'
# Out:
# text='What is the capital of France?'

# %%
llm.invoke(prompt)  # 잘 들어간다 -> 질문은 France로 들어가게 된 것
# Out:
# AIMessage(content='The capital of France is Paris.', additional_kwargs={}, response_metadata={'model': 'deepseek-r1:1.5b', 'created_at': '2026-03-12T16:58:14.2064375Z', 'done': True, 'done_reason': 'stop', 'total_duration': 846287300, 'load_duration': 336004100, 'prompt_eval_count': 10, 'prompt_eval_duration': 68910600, 'eval_count': 12, 'eval_duration': 431137300, 'logprobs': None, 'model_name': 'deepseek-r1:1.5b', 'model_provider': 'ollama'}, id='lc_run--019ce2fc-05ec-7521-9a20-b2452633cf73-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 10, 'output_tokens': 12, 'total_tokens': 22})

# %% [markdown]
# #### Base Message List

# %%
from langchain
